# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('cryptos')
data
# Out:
#        Unnamed: 0       id     name   timestamp          open          high  \
# 0               0  bitcoin  Bitcoin  2024-12-23  95094.273949  95094.273949
# 1               1  bitcoin  Bitcoin  2024-12-24  94644.910855  94644.910855
# 2               2  bitcoin  Bitcoin  2024-12-25  98695.714008  98695.714008
# 3               3  bitcoin  Bitcoin  2024-12-26  99344.954174  99344.954174
# 4               4  bitcoin  Bitcoin  2024-12-27  95678.312446  95678.312446
# ...           ...      ...      ...         ...           ...           ...
# 36495       36495    zcoin     Firo  2025-12-18      1.574282      1.574282
# 36496       36496    zcoin     Firo  2025-12-19      1.416434      1.416434
# 36497       36497    zcoin     Firo  2025-12-20      1.395952      1.395952
# 36498       36498    zcoin     Firo  2025-12-21      1.358657      1.358657
# 36499       36499    zcoin     Firo  2025-12-22      1.335084      1.339914
#
# ...

# %%
asset_esg = data.groupby('name')['esg'].first()

# 2. Get the distribution counts
esg_counts = asset_esg.value_counts().sort_index()

print("ESG Score Distribution (Unique Assets):")
print(esg_counts)
# Out:
# ESG Score Distribution (Unique Assets):
# esg
# 0     3
# 1    24
# 2    30
# 3    43
# Name: count, dtype: int64
